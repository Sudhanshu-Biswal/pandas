# %%
import pandas as pd
import numpy as np

# %%
# what are vectorized operations
a = np.array([1,2,3,4])
a*4
# Out:
# array([ 4,  8, 12, 16])

# %%
#problem in vectorized operation in vanilla python
s = ['cat','mat',None,'rat']
[i.startswith('c') for i in s] #list is also slow
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 #problem in vectorized operation in vanilla python
#       2 s = ['cat','mat',None,'rat']
# ----> 3 [i.startswith('c') for i in s]
#
# Input In [12], in <listcomp>(.0)
#       1 #problem in vectorized operation in vanilla python
#       2 s = ['cat','mat',None,'rat']
# ----> 3 [i.startswith('c') for i in s]
#
# AttributeError: 'NoneType' object has no attribute 'startswith'

# %%
#how pandas solves this issue?
s = pd.Series(['cat','mat',None,'rat'])
#string accessor
s.str.startswith('c')
#fast and optimized
# Out:
# 0     True
# 1    False
# 2     None
# 3    False
# dtype: object

# %%
#import titanic
df = pd.read_csv("/Users/sudhanshubiswal/Downloads/tested.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
#common functions

# %%
#lower/upper/capitalize/title
df['Name'].str.lower()
df['Name'].str.capitalize()
df['Name'].str.title()


#len
df["Name"][df["Name"].str.len() ==63].values[0]
#strip
df["Name"].str.strip()
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
#split -> get
df["last_name"] = df["Name"].str.split(",").str.get(0)
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked last_name
# 0  34.5      0      0  330911  7.8292   NaN        Q     Kelly
# 1  47.0      1      0  363272  7.0000   NaN        S    Wilkes

# %%
df[["title","firstname"]]=df["Name"].str.split(",").str.get(1).str.strip().str.split(" ",n=1,expand=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked last_name title  \
# 0   330911   7.8292   NaN        Q     Kelly   Mr.
# 1   363272   7.0000   NaN        S    Wilkes  Mrs.
# 2   240276   9.6875   NaN        Q     Myles   Mr.
# 3   315154   8.6625   NaN        S      Wirz   Mr.
# 4  3101298  12.2875   NaN        S  Hirvonen  Mrs.
#
#                        firstname
# 0                          James
# 1            James (Ellen Needs)
# 2                 Thomas Francis
# 3                         Albert
# 4  Alexander (Helga E Lindqvist)

# %%
df["title"].value_counts()
# Out:
# Mr.        240
# Miss.       78
# Mrs.        72
# Master.     21
# Col.         2
# Rev.         2
# Ms.          1
# Dr.          1
# Dona.        1
# Name: title, dtype: int64

# %%
# replace
df["title"] = df["title"].str.replace("Ms","Miss")

# %%
df["title"].value_counts()
# Out:
# Mr.        240
# Miss.       79
# Mrs.        72
# Master.     21
# Col.         2
# Rev.         2
# Dr.          1
# Dona.        1
# Name: title, dtype: int64

# %%
#filtering
#Startswith/endswith
df[df["firstname"].str.startswith('A')]
df[df["firstname"].str.endswith('A')]

#isdigit/isalpha
df[df["firstname"].str.isdigit()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, last_name, title, firstname]
# Index: []

# %%
# applying regex
#contains
#search join -> both case
df[df["firstname"].str.contains("john",case=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 9            901         0       3
# 12           904         1       1
# 28           920         0       1
# 64           956         0       1
# 84           976         0       2
# 116         1008         0       3
# 119         1011         1       2
# 121         1013         0       3
# 123         1015         0       3
# 124         1016         0       3
# 130         1022         0       3
# 148         1040         0       1
# 158         1050         0       1
# 192         1084         0       3
# 193         1085         0       2
# 202         1094         0       1
# 234         1126         0       1
# 256         1148         0       3
# 278         1170         0       2
# 287         1179         0       1
# 314         1206         1       1
# 330         1222         1       2
# 335         1227         0       1
# 342         1234         0       3
# 356         1248         1       1
# 362         1254         1       2
# 365         1257         1       3
# 387         1279         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 9                              Davies, Mr. John Samuel    male  21.0      2
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 28                             Brady, Mr. John Bertram    male  41.0      0
# 64                         Ryerson, Master. John Borie    male  13.0      2
# 84                               Lamb, Mr. John Joseph    male   NaN      0
# 116                                   Thomas, Mr. John    male   NaN      0
# 119    Chapman, Mrs. John Henry (Sara Elizabeth Lawry)  female  29.0      1
# 121                                  Kiernan, Mr. John    male   NaN      1
# 123                            Carver, Mr. Alfred John    male  28.0      0
# 124                                  Kennedy, Mr. John    male   NaN      0
# 130                            Spinner, Mr. Henry John    male  32.0      0
# 148                          Crafton, Mr. John Bertram    male   NaN      0
# 158                           Borebank, Mr. John James    male  42.0      0
# 192                  van Billiard, Master. Walter John    male  11.5      1
# 193                                  Lingane, Mr. John    male  61.0      0
# 202                             Astor, Col. John Jacob    male  47.0      1
# 234                          Cumings, Mr. John Bradley    male  39.0      1
# 256                                    Mahon, Mr. John    male   NaN      0
# 278                               Ware, Mr. John James    male  30.0      1
# 287                         Snyder, Mr. John Pillsbury    male  24.0      1
# 314              White, Mrs. John Stuart (Ella Holmes)  female  55.0      0
# 330  Davies, Mrs. John Morgan (Elizabeth Agnes Mary...  female  48.0      0
# 335                           Maguire, Mr. John Edward    male  30.0      0
# 342                              Sage, Mr. John George    male   NaN      1
# 356     Brown, Mrs. John Murray (Caroline Lane Lamson)  female  59.0      2
# 362       Ware, Mrs. John James (Florence Louise Long)  female  31.0      0
# 365                     Sage, Mrs. John (Annie Bullen)  female   NaN      1
# 387                                    Ashby, Mr. John    male  57.0      0
#
#      Parch           Ticket      Fare            Cabin Embarked     last_name  \
# 9        0        A/4 48871   24.1500              NaN        S        Davies
# 12       0            21228   82.2667              B45        S        Snyder
# 28       0           113054   30.5000              A21        S         Brady
# 64       2         PC 17608  262.3750  B57 B59 B63 B66        C       Ryerson
# 84       0           240261   10.7083              NaN        Q          Lamb
# 116      0             2681    6.4375              NaN        C        Thomas
# 119      0      SC/AH 29037   26.0000              NaN        S       Chapman
# 121      0           367227    7.7500              NaN        Q       Kiernan
# 123      0           392095    7.2500              NaN        S        Carver
# 124      0           368783    7.7500              NaN        Q       Kennedy
# 130      0  STON/OQ. 369943    8.0500              NaN        S       Spinner
# 148      0           113791   26.5500              NaN        S       Crafton
# 158      0           110489   26.5500              D22        S      Borebank
# 192      1         A/5. 851   14.5000              NaN        S  van Billiard
# 193      0           235509   12.3500              NaN        Q       Lingane
# 202      0         PC 17757  227.5250          C62 C64        C         Astor
# 234      0         PC 17599   71.2833              C85        C       Cumings
# 256      0        AQ/4 3130    7.7500              NaN        Q         Mahon
# 278      0         CA 31352   21.0000              NaN        S          Ware
# 287      0            21228   82.2667              B45        S        Snyder
# 314      0         PC 17760  135.6333              C32        C         White
# 330      2       C.A. 33112   36.7500              NaN        S        Davies
# 335      0           110469   26.0000             C106        S       Maguire
# 342      9         CA. 2343   69.5500              NaN        S          Sage
# 356      0            11769   51.4792             C101        S         Brown
# 362      0         CA 31352   21.0000              NaN        S          Ware
# 365      9         CA. 2343   69.5500              NaN        S          Sage
# 387      0           244346   13.0000              NaN        S         Ashby
#
#        title                                 firstname
# 9        Mr.                               John Samuel
# 12      Mrs.          John Pillsbury (Nelle Stevenson)
# 28       Mr.                              John Bertram
# 64   Master.                                John Borie
# 84       Mr.                               John Joseph
# 116      Mr.                                      John
# 119     Mrs.         John Henry (Sara Elizabeth Lawry)
# 121      Mr.                                      John
# 123      Mr.                               Alfred John
# 124      Mr.                                      John
# 130      Mr.                                Henry John
# 148      Mr.                              John Bertram
# 158      Mr.                                John James
# 192  Master.                               Walter John
# 193      Mr.                                      John
# 202     Col.                                John Jacob
# 234      Mr.                              John Bradley
# 256      Mr.                                      John
# 278      Mr.                                John James
# 287      Mr.                            John Pillsbury
# 314     Mrs.                 John Stuart (Ella Holmes)
# 330     Mrs.  John Morgan (Elizabeth Agnes Mary White)
# 335      Mr.                               John Edward
# 342      Mr.                               John George
# 356     Mrs.        John Murray (Caroline Lane Lamson)
# 362     Mrs.         John James (Florence Louise Long)
# 365     Mrs.                       John (Annie Bullen)
# 387      Mr.                                      John

# %%
#find lastname with start and char vowel
df[df["last_name"].str.contains("^[aeiouAEIOU].+[aeiouAEIOU]$")]
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 88           980         1       3       O'Donoghue, Ms. Bridget  female
# 190         1082         0       2          Angle, Mr. William A    male
# 358         1250         0       3          O'Keefe, Mr. Patrick    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
#
#       Age  SibSp  Parch    Ticket    Fare Cabin Embarked      last_name  \
# 88    NaN      0      0    364856    7.75   NaN        Q     O'Donoghue
# 190  34.0      1      0    226875   26.00   NaN        S          Angle
# 358   NaN      0      0    368402    7.75   NaN        Q        O'Keefe
# 414  39.0      0      0  PC 17758  108.90  C105        C  Oliva y Ocana
#
#      title  firstname
# 88   Miss.    Bridget
# 190    Mr.  William A
# 358    Mr.    Patrick
# 414  Dona.    Fermina

# %%
#slicing
df["Name"].str[::2]
# Out:
# 0                    Kly r ae
# 1            Wle,Ms ae ElnNes
# 2               Mls r hmsFacs
# 3                    Wr,M.Abr
# 4      Hroe,Ms lxne HlaELnqit
#                 ...
# 413                 Setr r ol
# 414            OiayOaa oa emn
# 415            Sehr r io iete
# 416                Wr,M.Feeik
# 417              Ptr atr ihe
# Name: Name, Length: 418, dtype: object
